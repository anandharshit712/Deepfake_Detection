# %%
import glob
import pandas as pd

# %%
path = 'C:/Users/anand/Downloads/MINOR PROJECT/Dataset/Deepfake Detection Challenge/dfdc_train_part_00/dfdc_train_part_0/'
video_files = glob.glob(path + "*mp4")

# %%
len(video_files)
# Out:
# 1334

# %%
names = []
for i in video_files:
    names.append(i.split("\\")[-1])

# %%
len(names)
# Out:
# 1334
